# %%
import random
 
maxTicketsAvailable = int(input("Enter the maximum tickets available - "))
 
participants = []
 
for temp in range(maxTicketsAvailable):
  st = "Enter the Participant name - "+ str(temp + 1) + " - "
  name = input(st)
  participants.append(name)
 
print("All our participants - ",participants)
 
n = random.randint(0,maxTicketsAvailable-1)
 
print("Winner of the lottery - ",participants[n])
# Out:
# Enter the maximum tickets available - 5
# Enter the Participant name - 1 - Harini
# Enter the Participant name - 2 - Keerthana
# Enter the Participant name - 3 - Hindthuja
# Enter the Participant name - 4 - Rajesh
# Enter the Participant name - 5 - Renu
# All our participants -  ['Harini', 'Keerthana', 'Hindthuja', 'Rajesh', 'Renu']
# Winner of the lottery -  Harini
